# %% [markdown]
# # C1: zadania — wprowadzenie do PyTorch

# %%
import torch

# %% [markdown]
# ## Zadanie 1 — Tworzenie tensorów
# Utwórz tensory:
# 1. A (3x4) wypełniony zerami
# 2. B (3x4) z rozkładu normalnego
# 3. C z liczbami od 10 do 19
# Wypisz shape i dtype.

# %%
# TODO

# %% [markdown]
# ## Zadanie 2 — Typy danych
# 1. Utwórz tensor jedynek float32 o rozmiarze 2x2
# 2. Zamień na int32 i float64
# Sprawdź dtype.

# %%
# TODO

# %% [markdown]
# ## Zadanie 3 — Reproducibility
# Ustaw seed=42 i wygeneruj tensor liczb losowych (2x2).
# Uruchom ponownie komórkę — czy wynik się zmienia?

# %%
# TODO

# %% [markdown]
# ## Zadanie 4 — Operacje matematyczne
# Dla losowych tensorów (3x3) oblicz:
# - sumę
# - różnicę
# - mnożenie elementowe
# - średnią.

# %%
# TODO

# %% [markdown]
# ## Zadanie 5 — Operacje in-place
# Skopiuj tensor x do x_copy (metoda clone()).
# Wykonaj x.add_(y).
# Sprawdź które tensory się zmieniły.

# %%
# TODO

# %% [markdown]
# ## Zadanie 6 — Reshape
# x = torch.arange(24)
# Przekształć do (4,6), (2,3,4), (12,2).

# %%
# TODO

# %% [markdown]
# ## Zadanie 7 — Indeksowanie
# Dla tensora (5x5) wyświetl:
# - trzeci wiersz
# - druga kolumna
# - podmacierz 2x2
# - elementy > 0.5

# %%
# TODO

# %% [markdown]
# ## Zadanie 8 — Statystyki
# Dla macierzy (4x6):
# - średnia wierszy
# - maksimum kolumn.

# %%
# TODO

# %% [markdown]
# ## Zadanie 9 — Warstwa liniowa
# Zaimplementuj y = xW + b używając torch.matmul, dzie x jest macierzą liniową 1x5, W ma rozmiar 5x3 oraz b 1x3

# %%
# TODO

# %% [markdown]
# ## Zadanie 10 — Batch processing
# macierz wejściowa x ma rozmiar 10x5. Oblicz wynik jedną operacją.

# %%
# TODO
